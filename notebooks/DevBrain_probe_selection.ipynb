# %%
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
from typing import List, Tuple
import matplotlib.pyplot as plt
import numpy as np
import loompy
import shoji
from tqdm import trange
import logging
import sys
# %load_ext line_profiler
logging.basicConfig(stream=sys.stdout, format='%(asctime)s - %(levelname)s - %(message)s', level=20)

# %%
db = shoji.connect()
db
# Out:
# Workspace with 5 workspaces, 0 dimensions and 0 tensors:
#   eel <Workspace>
#   images <Workspace>
#   refdb <Workspace>
#   scRNA <Workspace>
#   test <Workspace>

# %%
if "human_development" in db.refdb:
    del db.refdb.human_development
db.refdb.human_development = shoji.Workspace()

# %%
ws = db.refdb.human_development
ws._from_loom("/Users/stelin/Allbrain.agg.loom", dimension_names=("genes", "clusters"))
# Out:
# 100%|██████████| 1/1 [03:47<00:00, 227.85s/it]

# %%
ws
# Out:
# Workspace with 0 workspaces, 2 dimensions and 375 tensors:
#   clusters <Dimension of variable shape>
#   genes <Dimension of shape 33538>
#   Accession <Tensor Accession dtype='string' dims=('genes',), shape=(33538,)>
#   Age_10w <Tensor Age_10w dtype='int64' dims=('clusters',), shape=(616,)>
#   Age_11_5w <Tensor Age_11_5w dtype='int64' dims=('clusters',), shape=(616,)>
#   Age_12w <Tensor Age_12w dtype='int64' dims=('clusters',), shape=(616,)>
#   Age_13-13_5w <Tensor Age_13-13_5w dtype='int64' dims=('clusters',), shape=(616,)>
#   Age_14w <Tensor Age_14w dtype='int64' dims=('clusters',), shape=(616,)>
#   Age_5_5w <Tensor Age_5_5w dtype='int64' dims=('clusters',), shape=(616,)>
#   Age_5w <Tensor Age_5w dtype='int64' dims=('clusters',), shape=(616,)>
#   Age_6_6w <Tensor Age_6_6w dtype='int64' dims=('clusters',), shape=(616,)>
#   Age_6_7w <Tensor Age_6_7w dtype='int64' dims=('clusters',), shape=(616,)>
#   Age_6_9w <Tensor Age_6_9w dtype='int64' dims=('clusters',), shape=(616,)>
#   Age_6w <Tensor Age_6w dtype='int64' dims=('clusters',), shape=(616,)>
#   Age_7_5w <Tensor Age_7_5w dtype='int64' dims=('clusters',), shape=(616,)>
#   Age_8_1w <Tensor Age_8_1w dtype='int64' dims=('clusters',), shape=(616,)>
#   Age_8_5w <Tensor Age_8_5w dtype='int64' dims=('clusters',), shape=(616,)>
#   Age_8w <Tensor Age_8w dtype='int64' dims=('clusters',), shape=(616,)>
#   Age_9_2w <Tensor Age_9_2w dtype='int64' dims=('clusters',), shape=(616,)>
#   Age_9_5w <Tensor Age_9_5w dtype='int64' dims=('clusters',), shape=(616,)>
#   AutoAnnotation <Tensor AutoAnnotation dtype='string' dims=('clusters',), shape=(616,)>
#   Chromosome <Tensor Chromosome dtype='string' dims=('genes',), shape=(33538,)>
#   Clusters <Tensor Clusters dtype='int64' dims=('clusters',), shape=(616,)>
#   Config <Tensor Config dtype='string' dims=(), shape=()>
#   CreationDate <Tensor CreationDate dtype='string' dims=(), shape=()>
#   End <Tensor End dtype='int64' dims=('genes',), shape=(33538,)>
#   Enrichment <Tensor Enrichment dtype='float64' dims=('clusters', 'genes'), shape=(616, 33538)>
#   Expression <Tensor Expression dtype='float64' dims=('clusters', 'genes'), shape=(616, 33538)>
#   Gene <Tensor Gene dtype='string' dims=('genes',), shape=(33538,)>
#   LOOM_SPEC_VERSION <Tensor LOOM_SPEC_VERSION dtype='string' dims=(), shape=()>
#   Linkage <Tensor Linkage dtype='float64' dims=(615, 4), shape=(615, 4)>
#   MarkerGenes <Tensor MarkerGenes dtype='string' dims=('clusters',), shape=(616,)>
#   MarkerRobustness <Tensor MarkerRobustness dtype='string' dims=('clusters',), shape=(616,)>
#   MarkerSelectivity <Tensor MarkerSelectivity dtype='string' dims=('clusters',), shape=(616,)>
#   MarkerSpecificity <Tensor MarkerSpecificity dtype='string' dims=('clusters',), shape=(616,)>
#   MultilevelMarkers <Tensor MultilevelMarkers dtype='float64' dims=('genes', 4), shape=(33538, 4)>
#   NCells <Tensor NCells dtype='int64' dims=('clusters',), shape=(616,)>
#   Outliers <Tensor Outliers dtype='float64' dims=('clusters',), shape=(616,)>
#   SampleID_10X101_1 <Tensor SampleID_10X101_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X101_2 <Tensor SampleID_10X101_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X101_3 <Tensor SampleID_10X101_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X101_4 <Tensor SampleID_10X101_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X101_5 <Tensor SampleID_10X101_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X101_6 <Tensor SampleID_10X101_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X101_7 <Tensor SampleID_10X101_7 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X101_8 <Tensor SampleID_10X101_8 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X102_1 <Tensor SampleID_10X102_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X102_2 <Tensor SampleID_10X102_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X102_3 <Tensor SampleID_10X102_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X102_4 <Tensor SampleID_10X102_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X102_5 <Tensor SampleID_10X102_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X102_6 <Tensor SampleID_10X102_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X102_7 <Tensor SampleID_10X102_7 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X102_8 <Tensor SampleID_10X102_8 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X104_1 <Tensor SampleID_10X104_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X104_3 <Tensor SampleID_10X104_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X104_4 <Tensor SampleID_10X104_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X104_5 <Tensor SampleID_10X104_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X104_6 <Tensor SampleID_10X104_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X104_7 <Tensor SampleID_10X104_7 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X104_8 <Tensor SampleID_10X104_8 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X109_2 <Tensor SampleID_10X109_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X109_3 <Tensor SampleID_10X109_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X109_4 <Tensor SampleID_10X109_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X109_7 <Tensor SampleID_10X109_7 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X110_4 <Tensor SampleID_10X110_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X110_5 <Tensor SampleID_10X110_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X110_6 <Tensor SampleID_10X110_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X111_1 <Tensor SampleID_10X111_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X111_2 <Tensor SampleID_10X111_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X112_1 <Tensor SampleID_10X112_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X112_2 <Tensor SampleID_10X112_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X114_1 <Tensor SampleID_10X114_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X114_3 <Tensor SampleID_10X114_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X114_4 <Tensor SampleID_10X114_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X115_1 <Tensor SampleID_10X115_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X115_2 <Tensor SampleID_10X115_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X115_3 <Tensor SampleID_10X115_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X115_5 <Tensor SampleID_10X115_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X115_6 <Tensor SampleID_10X115_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X115_7 <Tensor SampleID_10X115_7 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X115_8 <Tensor SampleID_10X115_8 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X116_1 <Tensor SampleID_10X116_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X116_2 <Tensor SampleID_10X116_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X116_3 <Tensor SampleID_10X116_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X116_4 <Tensor SampleID_10X116_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X116_5 <Tensor SampleID_10X116_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X116_6 <Tensor SampleID_10X116_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X116_7 <Tensor SampleID_10X116_7 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X116_8 <Tensor SampleID_10X116_8 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X118_1 <Tensor SampleID_10X118_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X118_2 <Tensor SampleID_10X118_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X118_3 <Tensor SampleID_10X118_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X118_4 <Tensor SampleID_10X118_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X118_5 <Tensor SampleID_10X118_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X118_6 <Tensor SampleID_10X118_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X118_7 <Tensor SampleID_10X118_7 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X118_8 <Tensor SampleID_10X118_8 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X119_1 <Tensor SampleID_10X119_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X119_2 <Tensor SampleID_10X119_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X119_3 <Tensor SampleID_10X119_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X119_4 <Tensor SampleID_10X119_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X119_5 <Tensor SampleID_10X119_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X119_6 <Tensor SampleID_10X119_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X119_7 <Tensor SampleID_10X119_7 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X119_8 <Tensor SampleID_10X119_8 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X122_1 <Tensor SampleID_10X122_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X122_2 <Tensor SampleID_10X122_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X122_3 <Tensor SampleID_10X122_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X122_5 <Tensor SampleID_10X122_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X122_6 <Tensor SampleID_10X122_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X122_7 <Tensor SampleID_10X122_7 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X122_8 <Tensor SampleID_10X122_8 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X123_1 <Tensor SampleID_10X123_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X123_2 <Tensor SampleID_10X123_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X123_3 <Tensor SampleID_10X123_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X123_4 <Tensor SampleID_10X123_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X123_5 <Tensor SampleID_10X123_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X123_6 <Tensor SampleID_10X123_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X123_7 <Tensor SampleID_10X123_7 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X123_8 <Tensor SampleID_10X123_8 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X124_1 <Tensor SampleID_10X124_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X124_2 <Tensor SampleID_10X124_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X124_3 <Tensor SampleID_10X124_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X124_4 <Tensor SampleID_10X124_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X124_5 <Tensor SampleID_10X124_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X124_6 <Tensor SampleID_10X124_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X124_7 <Tensor SampleID_10X124_7 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X124_8 <Tensor SampleID_10X124_8 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X125_1 <Tensor SampleID_10X125_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X125_2 <Tensor SampleID_10X125_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X125_3 <Tensor SampleID_10X125_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X125_4 <Tensor SampleID_10X125_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X125_5 <Tensor SampleID_10X125_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X125_6 <Tensor SampleID_10X125_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X126_1 <Tensor SampleID_10X126_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X126_2 <Tensor SampleID_10X126_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X126_3 <Tensor SampleID_10X126_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X126_4 <Tensor SampleID_10X126_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X126_7 <Tensor SampleID_10X126_7 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X126_8 <Tensor SampleID_10X126_8 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X132_1 <Tensor SampleID_10X132_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X132_2 <Tensor SampleID_10X132_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X132_3 <Tensor SampleID_10X132_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X132_4 <Tensor SampleID_10X132_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X132_5 <Tensor SampleID_10X132_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X132_6 <Tensor SampleID_10X132_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X132_7 <Tensor SampleID_10X132_7 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X132_8 <Tensor SampleID_10X132_8 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X147_1 <Tensor SampleID_10X147_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X147_2 <Tensor SampleID_10X147_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X148_1 <Tensor SampleID_10X148_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X148_2 <Tensor SampleID_10X148_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X152_1 <Tensor SampleID_10X152_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X152_2 <Tensor SampleID_10X152_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X152_3 <Tensor SampleID_10X152_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X152_4 <Tensor SampleID_10X152_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X152_5 <Tensor SampleID_10X152_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X152_6 <Tensor SampleID_10X152_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X152_7 <Tensor SampleID_10X152_7 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X152_8 <Tensor SampleID_10X152_8 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X154_1 <Tensor SampleID_10X154_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X154_2 <Tensor SampleID_10X154_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X154_3 <Tensor SampleID_10X154_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X154_4 <Tensor SampleID_10X154_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X156_1 <Tensor SampleID_10X156_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X156_2 <Tensor SampleID_10X156_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X156_3 <Tensor SampleID_10X156_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X156_4 <Tensor SampleID_10X156_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X156_5 <Tensor SampleID_10X156_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X156_6 <Tensor SampleID_10X156_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X156_7 <Tensor SampleID_10X156_7 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X156_8 <Tensor SampleID_10X156_8 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X157_1 <Tensor SampleID_10X157_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X157_2 <Tensor SampleID_10X157_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X162_1 <Tensor SampleID_10X162_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X162_2 <Tensor SampleID_10X162_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X162_3 <Tensor SampleID_10X162_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X163_1 <Tensor SampleID_10X163_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X163_2 <Tensor SampleID_10X163_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X163_3 <Tensor SampleID_10X163_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X163_4 <Tensor SampleID_10X163_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X163_7 <Tensor SampleID_10X163_7 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X163_8 <Tensor SampleID_10X163_8 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X164_1 <Tensor SampleID_10X164_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X164_2 <Tensor SampleID_10X164_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X164_3 <Tensor SampleID_10X164_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X164_4 <Tensor SampleID_10X164_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X164_5 <Tensor SampleID_10X164_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X164_6 <Tensor SampleID_10X164_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X164_7 <Tensor SampleID_10X164_7 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X165_1 <Tensor SampleID_10X165_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X165_3 <Tensor SampleID_10X165_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X165_4 <Tensor SampleID_10X165_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X167_1 <Tensor SampleID_10X167_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X167_2 <Tensor SampleID_10X167_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X167_5 <Tensor SampleID_10X167_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X167_6 <Tensor SampleID_10X167_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X167_7 <Tensor SampleID_10X167_7 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X167_8 <Tensor SampleID_10X167_8 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X168_1 <Tensor SampleID_10X168_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X168_2 <Tensor SampleID_10X168_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X168_3 <Tensor SampleID_10X168_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X168_4 <Tensor SampleID_10X168_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X168_5 <Tensor SampleID_10X168_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X168_6 <Tensor SampleID_10X168_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X169_1 <Tensor SampleID_10X169_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X169_2 <Tensor SampleID_10X169_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X169_4 <Tensor SampleID_10X169_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X169_5 <Tensor SampleID_10X169_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X169_6 <Tensor SampleID_10X169_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X169_7 <Tensor SampleID_10X169_7 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X169_8 <Tensor SampleID_10X169_8 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X170_1 <Tensor SampleID_10X170_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X170_2 <Tensor SampleID_10X170_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X170_3 <Tensor SampleID_10X170_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X170_4 <Tensor SampleID_10X170_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X177_4 <Tensor SampleID_10X177_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X177_5 <Tensor SampleID_10X177_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X177_6 <Tensor SampleID_10X177_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X178_1 <Tensor SampleID_10X178_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X178_2 <Tensor SampleID_10X178_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X178_3 <Tensor SampleID_10X178_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X178_4 <Tensor SampleID_10X178_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X178_5 <Tensor SampleID_10X178_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X179_4 <Tensor SampleID_10X179_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X183_1 <Tensor SampleID_10X183_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X183_2 <Tensor SampleID_10X183_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X183_3 <Tensor SampleID_10X183_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X185_1 <Tensor SampleID_10X185_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X185_2 <Tensor SampleID_10X185_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X185_4 <Tensor SampleID_10X185_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X185_5 <Tensor SampleID_10X185_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X185_6 <Tensor SampleID_10X185_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X185_7 <Tensor SampleID_10X185_7 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X185_8 <Tensor SampleID_10X185_8 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X186_1 <Tensor SampleID_10X186_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X186_3 <Tensor SampleID_10X186_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X186_4 <Tensor SampleID_10X186_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X187_1 <Tensor SampleID_10X187_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X187_2 <Tensor SampleID_10X187_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X187_3 <Tensor SampleID_10X187_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X187_4 <Tensor SampleID_10X187_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X187_5 <Tensor SampleID_10X187_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X187_6 <Tensor SampleID_10X187_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X187_7 <Tensor SampleID_10X187_7 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X187_8 <Tensor SampleID_10X187_8 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X188_1 <Tensor SampleID_10X188_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X188_2 <Tensor SampleID_10X188_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X188_3 <Tensor SampleID_10X188_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X188_4 <Tensor SampleID_10X188_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X196_1 <Tensor SampleID_10X196_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X196_2 <Tensor SampleID_10X196_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X196_5 <Tensor SampleID_10X196_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X196_6 <Tensor SampleID_10X196_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X197_1 <Tensor SampleID_10X197_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X197_2 <Tensor SampleID_10X197_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X197_5 <Tensor SampleID_10X197_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X197_6 <Tensor SampleID_10X197_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X198_1 <Tensor SampleID_10X198_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X198_2 <Tensor SampleID_10X198_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X198_3 <Tensor SampleID_10X198_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X198_4 <Tensor SampleID_10X198_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X198_5 <Tensor SampleID_10X198_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X198_6 <Tensor SampleID_10X198_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X199_1 <Tensor SampleID_10X199_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X199_2 <Tensor SampleID_10X199_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X199_3 <Tensor SampleID_10X199_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X199_4 <Tensor SampleID_10X199_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X199_5 <Tensor SampleID_10X199_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X199_6 <Tensor SampleID_10X199_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X199_7 <Tensor SampleID_10X199_7 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X199_8 <Tensor SampleID_10X199_8 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X200_1 <Tensor SampleID_10X200_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X200_2 <Tensor SampleID_10X200_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X200_3 <Tensor SampleID_10X200_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X201_1 <Tensor SampleID_10X201_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X201_2 <Tensor SampleID_10X201_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X207_1 <Tensor SampleID_10X207_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X207_2 <Tensor SampleID_10X207_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X207_3 <Tensor SampleID_10X207_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X207_4 <Tensor SampleID_10X207_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X208_1 <Tensor SampleID_10X208_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X208_2 <Tensor SampleID_10X208_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X208_3 <Tensor SampleID_10X208_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X208_4 <Tensor SampleID_10X208_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X208_5 <Tensor SampleID_10X208_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X208_6 <Tensor SampleID_10X208_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X208_7 <Tensor SampleID_10X208_7 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X208_8 <Tensor SampleID_10X208_8 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X209_1 <Tensor SampleID_10X209_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X209_2 <Tensor SampleID_10X209_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X209_3 <Tensor SampleID_10X209_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X210_1 <Tensor SampleID_10X210_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X210_2 <Tensor SampleID_10X210_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X210_3 <Tensor SampleID_10X210_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X210_4 <Tensor SampleID_10X210_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X210_5 <Tensor SampleID_10X210_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X210_6 <Tensor SampleID_10X210_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X210_7 <Tensor SampleID_10X210_7 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X210_8 <Tensor SampleID_10X210_8 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X211_1 <Tensor SampleID_10X211_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X211_2 <Tensor SampleID_10X211_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X211_3 <Tensor SampleID_10X211_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X211_4 <Tensor SampleID_10X211_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X211_5 <Tensor SampleID_10X211_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X212_1 <Tensor SampleID_10X212_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X212_2 <Tensor SampleID_10X212_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X212_3 <Tensor SampleID_10X212_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X212_4 <Tensor SampleID_10X212_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X212_5 <Tensor SampleID_10X212_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X212_6 <Tensor SampleID_10X212_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X213_1 <Tensor SampleID_10X213_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X213_2 <Tensor SampleID_10X213_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X213_3 <Tensor SampleID_10X213_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X213_4 <Tensor SampleID_10X213_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X226_2 <Tensor SampleID_10X226_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X251_1 <Tensor SampleID_10X251_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X251_2 <Tensor SampleID_10X251_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X251_3 <Tensor SampleID_10X251_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X251_4 <Tensor SampleID_10X251_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X251_5 <Tensor SampleID_10X251_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X251_6 <Tensor SampleID_10X251_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X252_2 <Tensor SampleID_10X252_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X252_3 <Tensor SampleID_10X252_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X252_4 <Tensor SampleID_10X252_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X89_1 <Tensor SampleID_10X89_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X89_2 <Tensor SampleID_10X89_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X89_3 <Tensor SampleID_10X89_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X89_4 <Tensor SampleID_10X89_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X89_5 <Tensor SampleID_10X89_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X89_6 <Tensor SampleID_10X89_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X89_7 <Tensor SampleID_10X89_7 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X89_8 <Tensor SampleID_10X89_8 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X92_1 <Tensor SampleID_10X92_1 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X92_2 <Tensor SampleID_10X92_2 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X92_3 <Tensor SampleID_10X92_3 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X92_4 <Tensor SampleID_10X92_4 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X99_5 <Tensor SampleID_10X99_5 dtype='int64' dims=('clusters',), shape=(616,)>
#   SampleID_10X99_6 <Tensor SampleID_10X99_6 dtype='int64' dims=('clusters',), shape=(616,)>
#   Selected <Tensor Selected dtype='int64' dims=('genes',), shape=(33538,)>
#   Sex_ <Tensor Sex_ dtype='int64' dims=('clusters',), shape=(616,)>
#   Start <Tensor Start dtype='int64' dims=('genes',), shape=(33538,)>
#   Strand <Tensor Strand dtype='string' dims=('genes',), shape=(33538,)>
#   Tissue_Cerebellum <Tensor Tissue_Cerebellum dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Cortex <Tensor Tissue_Cortex dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Cortical hem <Tensor Tissue_Cortical hem dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Diencephalon <Tensor Tissue_Diencephalon dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Dorsal midbrain <Tensor Tissue_Dorsal midbrain dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Enthorinal cortex <Tensor Tissue_Enthorinal cortex dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Forebrain <Tensor Tissue_Forebrain dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Forebrain cortex <Tensor Tissue_Forebrain cortex dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Frontotemporal cortex <Tensor Tissue_Frontotemporal cortex dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Hindbrain <Tensor Tissue_Hindbrain dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Hippocampus <Tensor Tissue_Hippocampus dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Hypothalamus <Tensor Tissue_Hypothalamus dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Lower cortex <Tensor Tissue_Lower cortex dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Medulla <Tensor Tissue_Medulla dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Mesencephalon <Tensor Tissue_Mesencephalon dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Occipital cortex <Tensor Tissue_Occipital cortex dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Pons <Tensor Tissue_Pons dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Pons-Cereb <Tensor Tissue_Pons-Cereb dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Pons-Medulla <Tensor Tissue_Pons-Medulla dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Spinal cord <Tensor Tissue_Spinal cord dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Spinal cord cervical <Tensor Tissue_Spinal cord cervical dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Spinal cord lumbar <Tensor Tissue_Spinal cord lumbar dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Spinal cord thoracic <Tensor Tissue_Spinal cord thoracic dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Striatum <Tensor Tissue_Striatum dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Subcortex <Tensor Tissue_Subcortex dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Subcortical forebrain <Tensor Tissue_Subcortical forebrain dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Tel-diencephalon <Tensor Tissue_Tel-diencephalon dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Telencephalon <Tensor Tissue_Telencephalon dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Thalamus <Tensor Tissue_Thalamus dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Upper cortex <Tensor Tissue_Upper cortex dtype='int64' dims=('clusters',), shape=(616,)>
#   Tissue_Ventral midbrain <Tensor Tissue_Ventral midbrain dtype='int64' dims=('clusters',), shape=(616,)>
#   Trinaries <Tensor Trinaries dtype='float64' dims=('clusters', 'genes'), shape=(616, 33538)>
#   Valid <Tensor Valid dtype='int64' dims=('genes',), shape=(33538,)>

# %%
import scipy.cluster.hierarchy as hc
ws = db.refdb.human_development


def enrichment(ws: shoji.WorkspaceManager) -> np.ndarray:
    """
    Compute gene enrichment for a workspace of aggregate data, by cluster

    Args:
        ws		The workspace

    Returns:
        enrichment		A (n_clusters, n_genes) matrix of gene enrichment scores
    """
    n_clusters = len(ws.clusters)
    view = ws[:]

    totals = view.Expression.sum(axis=1)
    x_norm = (view.Expression.T / totals * np.median(totals)).T
    gene_sums = x_norm.sum(axis=0)
    enrichment = np.zeros_like(x_norm)
    for j in range(n_clusters):
        enrichment[j, :] = (x_norm[j, :] + 1) / (((gene_sums - x_norm[j, :]) / n_clusters) + 1)
    return enrichment


def enrichment_by_groups(ws: shoji.WorkspaceManager, labels: np.ndarray) -> np.ndarray:
    """
    Compute gene enrichment for a workspace of aggregate data, by groups of clusters

    Args:
        ws		The workspace
        labels	Labels (0, 1, ...) indicating the cluster groups

    Returns:
        enrichment		A (n_groups, n_genes) matrix of gene enrichment scores
    """
    n_clusters = labels.max() + 1
    view = ws[:]
    data = (view.Expression.T * view.NCells).T
    grouped = np.zeros((n_clusters, data.shape[1]))
    for j in range(n_clusters):
        grouped[j, :] = data[labels == j, :].sum(axis=0) / view.NCells[labels == j].sum()

    totals = grouped.sum(axis=1)
    x_norm = (grouped.T / totals * np.median(totals)).T
    gene_sums = x_norm.sum(axis=0)
    enrichment = np.zeros_like(x_norm)
    for j in range(n_clusters):
        enrichment[j, :] = (x_norm[j, :] + 1) / (((gene_sums - x_norm[j, :]) / n_clusters) + 1)
    return enrichment


def multilevel_feature_selection(ws: shoji.WorkspaceManager, preselected=[]):
    n_clusters = len(ws.clusters)

    n = 2
    selected: List[int] = []
    genes = ws[:].Gene
    for gene in preselected:
        if gene in genes:
            selected.append(np.where(genes == gene)[0][0])

    # Select from the dendrogram
    while n < n_clusters // 2:
        labels = hc.cut_tree(ws[:].Linkage, n_clusters=n).T[0]
        enr = enrichment_by_groups(ws, labels)
        for j in range(n):
            top = np.argsort(-enr[j, :])
            for t in top:
                if t not in selected:
                    selected.append(t)
                    break
        n *= 2

    # Select from the leaves
    enr = enrichment(ws)
    for j in range(n_clusters):
        top = np.argsort(-enr[j, :])
        for t in top:
            if t not in selected:
                selected.append(t)
                break
    return selected

# %%
enr = multilevel_feature_selection(ws, preselected=["PNMT",
"AQP4",
"GJA1",
"CD4",
"IL7R",
"TRAC",
"CCL5",
"CD8",
"GZMA",
"GZMK",
"CDK1",
"PCNA",
"TOP2A",
"UBE2C",
"CHAT",
"SLC18A3",
"SLC5A7",
"CST3",
"HLA-DBP1",
"HLA-DQB1","SLC6A3",
"TH",
"CLDN5",
"FLT1",
"VWF",
"FOXJ1",
"TMEM212",
"COL1A1",
"COL3A1",
"DCN",
"LOX",
"LUM",
"GAD1",
"GAD2",
"SLC32A1",
"SLC17A6",
"SLC17A7",
"SLC17A8",
"SLC6A5",
"SLC6A9",
"ACSL1",
"APOE",
"C1QA",
"C1QB",
"C1QC",
"CCL18",
"CCL20",
"CCL3",
"CCL3L1",
"CCL4",
"CCL4L2",
"CD163",
"CD84",
"CD93",
"CSF2RA",
"CTSB",
"CXCL8",
"CYBB",
"DAB2",
"EGR3",
"EMB",
"EREG",
"FCGBP",
"FCGR3A",
"FGL1",
"FOLR2",
"GPNMB",
"GPR183",
"GPR34",
"HBG1",
"HK2",
"HMOX1",
"IBSP",
"IL1B",
"IL1R2",
"KYNU",
"LSP1",
"MSR1",
"NAV3",
"OLR1",
"OSM",
"P2RY12",
"PPBP",
"RAB20",
"S100A4",
"S100A8",
"S100A9",
"SCML4",
"SLAMF8",
"SLC02B1",
"SLC16A10",
"SPP1",
"STAB1",
"TFEC",
"TGFBI",
"TMIGD3",
"TREM2",
"TYROBP",
"VAMP8",
"VSIG4",
"AIF1",
"HEXB",
"SLC18A1",
"SLC18A2",
"CD36",
"CD74",
"IFI30",
"LYZ",
"PSAP",
"CD79B",
"MS4A1",
"EBF1",
"EBF2",
"EBF3",
"NHLH1",
"NHLH2",
"RBFOX3",
"STMN2",
"STMN3",
"GNLY",
"NKG7",
"DBH",
"MBP",
"MOG",
"PLP1",
"SOX10",
"PDGFRA",
"MRC1",
"MZB1",
"TXNDC5",
"IRF8",
"TCF4",
"FABP5",
"FABP7",
"HOPX",
"PAX6",
"MPZ",
"FEV",
"TPH2",
"CD2",
"CD3D",
"CD69",
"GZMB",
"IGKC",
"JCHAIN",
"KLRB1",
"LTB",
"TRBC2",
"HMGB2",
"STMN1",
"TUBA1B",
"FOXP3",
"IL32",
"ACTA2",
"TAGLN"])

# %%
for g in sorted(ws[:].Gene[enr[152+287:152+287+100]]):
    print(g)
# Out:
# AC092691.1
# BHLHE22
# CADM1
# CADPS2
# CARTPT
# CCNB2
# CDH18
# CDK14
# CHRM3
# CLYBL
# CNTN1
# CNTN4
# CNTNAP4
# COL25A1
# CRH
# DBI
# DCLK2
# DLGAP1
# DNAJC12
# DSCAML1
# EN1
# EPHA5
# EPHA6
# FAM19A1
# FOXD3-AS1
# FSTL5
# GAP43
# GBX1
# GPC6
# GRIA2
# GRIP1
# GRM5
# HDC
# HOTAIRM1
# INPP4B
# ISL1
# KAZN
# KCNQ3
# KIF26B-AS1
# KIZ
# KLHL1
# LDB2
# LHFPL3
# LHFPL6
# LINC02381
# LINGO2
# LMO1
# LUZP2
# MDGA2
# MEF2C
# MEST
# MSRA
# NCAM2
# NDST3
# NEGR1
# NEUROD2
# NKX2-1
# NLGN1
# NNAT
# NPY
# NR2F2
# NR2F2-AS1
# NRCAM
# NRXN1
# NTM
# NTRK3
# PCSK1N
# PDE1A
# PDE4D
# PPP2R2B
# PRKCA
# PRKCB
# PTPRG
# SCGN
# SEMA6D
# SGCZ
# SHISA6
# SHTN1
# SIM1
# SIRT2
# SIX3
# SLIT3
# SMC4
# SNTG1
# SPOCK1
# SSTR2
# ST18
# SYN3
# TBCA
# TENM4
# THRB
# TSHZ3
# TUBA1A
# UBE2S
# UCHL1
# VCAN
# ZIC1
# ZNF804A
# ZNF804B
# ZSWIM5
